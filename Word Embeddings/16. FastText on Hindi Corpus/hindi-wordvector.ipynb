# %%
import os
import re
import fasttext
import numpy as np
import pandas as pd

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/hindi-text-short-summarization-corpus/train.csv
# /kaggle/input/hindi-text-short-summarization-corpus/test.csv

# %% [markdown]
# ### 1)  Text Preprocessing

# %%
def preprocess(file_path, file_name):
    
    df = pd.read_csv(file_path)
    text = ' '.join(list(df['article'].values))
    text = re.sub("\n","",text)
    text = re.sub(r'[।!:.,;()_’?"\/@]', r'', text)
    text = text.replace(u"'",'')
    text = text.replace(u'\u200d','')
    text = text.replace(u'\xa0','')
    text = re.sub(r'[a-zA-Z]+', '', text)
    text = re.sub(r'\s+', ' ', text)
    text = text.strip()

    fd = open(file_name + '.txt','w')
    fd.write(text)
    fd.close()
    print(file_name ,'created!')
    
preprocess('/kaggle/input/hindi-text-short-summarization-corpus/test.csv', 'testing')
preprocess('/kaggle/input/hindi-text-short-summarization-corpus/train.csv', 'training')
# Out:
# testing created!
# training created!

# %% [markdown]
# ### 2) Training FastText Model

# %%
model = fasttext.train_unsupervised('/kaggle/working/training.txt', model='cbow')

model.save_model("model_cbow.bin")
# Out:
# Read 92M words
# Number of words:  178308
# Number of labels: 0
# Progress: 100.0% words/sec/thread:   60573 lr:  0.000000 avg.loss:  0.932679 ETA:   0h 0m 0s  1.6% words/sec/thread:   61298 lr:  0.049195 avg.loss:  2.265252 ETA:   0h41m17s 0.049126 avg.loss:  2.225720 ETA:   0h41m15s  5.6% words/sec/thread:   61072 lr:  0.047185 avg.loss:  1.857195 ETA:   0h39m45s 1.840576 ETA:   0h39m29s37m 6s 16.1% words/sec/thread:   61122 lr:  0.041955 avg.loss:  1.683501 ETA:   0h35m19s 16.4% words/sec/thread:   61135 lr:  0.041776 avg.loss:  1.679926 ETA:   0h35m 9s% words/sec/thread:   61135 lr:  0.041416 avg.loss:  1.674047 ETA:   0h34m51s 1.670856 ETA:   0h34m44s 0.040678 avg.loss:  1.659951 ETA:   0h34m13s lr:  0.037903 avg.loss:  1.608631 ETA:   0h31m51s 24.7% words/sec/thread:   61204 lr:  0.037664 avg.loss:  1.601927 ETA:   0h31m39s 26.0% words/sec/thread:   61199 lr:  0.037003 avg.loss:  1.581677 ETA:   0h31m 6s words/sec/thread:   61200 lr:  0.036981 avg.loss:  1.581043 ETA:   0h31m 5s% words/sec/thread:   61209 lr:  0.036386 avg.loss:  1.564186 ETA:   0h30m35s avg.loss:  1.531964 ETA:   0h29m34s 0.034977 avg.loss:  1.529321 ETA:   0h29m30s 0.034427 avg.loss:  1.516836 ETA:   0h29m 6s words/sec/thread:   60633 lr:  0.030200 avg.loss:  1.444123 ETA:   0h25m37s  60628 lr:  0.030165 avg.loss:  1.443676 ETA:   0h25m36s 39.8% words/sec/thread:   60622 lr:  0.030076 avg.loss:  1.442577 ETA:   0h25m31s 40.6% words/sec/thread:   60612 lr:  0.029684 avg.loss:  1.437302 ETA:   0h25m11s 0.029164 avg.loss:  1.430056 ETA:   0h24m45s 0.027418 avg.loss:  1.405852 ETA:   0h23m17s avg.loss:  1.403546 ETA:   0h23m 6s 45.7% words/sec/thread:   60577 lr:  0.027129 avg.loss:  1.402189 ETA:   0h23m 2s 50.4% words/sec/thread:   60662 lr:  0.024779 avg.loss:  1.371362 ETA:   0h21m 1s  60666 lr:  0.024732 avg.loss:  1.370932 ETA:   0h20m58s 0.023498 avg.loss:  1.358243 ETA:   0h19m56s  60633 lr:  0.023406 avg.loss:  1.357474 ETA:   0h19m51s 55.2% words/sec/thread:   60620 lr:  0.022408 avg.loss:  1.347827